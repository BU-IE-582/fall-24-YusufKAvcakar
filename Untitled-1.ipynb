# %%
import pandas as pd
import numpy as np

# %%
input_df = pd.read_csv("hw1_input.csv")

# %% [markdown]
# Normalization of the input data

# %%
from sklearn.preprocessing import StandardScaler

x = input_df.values
x_normalized = StandardScaler().fit_transform(x)

# %% [markdown]
# Control of the mean and standard deviation of normalized data

# %%
np.mean(x_normalized), np.std(x_normalized)
# Out:
# (np.float64(-3.858909780987557e-17), np.float64(1.0))

# %%
from sklearn.decomposition import PCA

pca_breast = PCA(n_components=2)
principalComponents_breast = pca_breast.fit_transform(x_normalized)
explained_variance = pca_breast.explained_variance_ratio_

# %%
print('Explained variation per principal component: {}'.format(explained_variance))
pca_breast.components_
# Out:
# Explained variation per principal component: [0.20715348 0.11070825]
# array([[-0.10132741,  0.62417829,  0.07105448,  0.62413737, -0.02104923,
#          0.02599671, -0.05422779, -0.01872008,  0.03921288,  0.44510015,
#          0.0384219 ],
#        [ 0.31540884, -0.0097185 ,  0.05571604,  0.01882426,  0.26625903,
#          0.00281543, -0.26599034, -0.55949874,  0.56475324, -0.01282947,
#         -0.35094425]])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.bar(range(1, len(explained_variance) + 1), explained_variance, color='b', label='Açıklanan Varyans')
# plt.plot(range(1, len(explained_variance) + 1), np.cumsum(explained_variance), marker='o', color='r', label='Kümülatif Açıklanan Varyans')
plt.xlabel('Bileşen Sayısı')
plt.ylabel('Açıklanan Varyans Oranı')
plt.title('PCA Bileşenlerinin Açıklanan Varyans Oranları')
plt.legend()
plt.show()

# %% [markdown]
# Variation explained by principal components is seen above and these values are so low; therefore, we will increase the component number.

# %%
for i in range(len(input_df.columns)):
    pca_breast_variable = PCA(n_components=i)
    principalComponents_breast = pca_breast_variable.fit_transform(x_normalized)
    explained_variance_trial = pca_breast_variable.explained_variance_ratio_
    print('While there is '+str(i)+' principal components, explained variation per principal component: {}'.format(explained_variance_trial))
# Out:
# While there is 0 principal components, explained variation per principal component: []
# While there is 1 principal components, explained variation per principal component: [0.20715348]
# While there is 2 principal components, explained variation per principal component: [0.20715348 0.11070825]
# While there is 3 principal components, explained variation per principal component: [0.20715348 0.11070825 0.10003384]
# While there is 4 principal components, explained variation per principal component: [0.20715348 0.11070825 0.10003384 0.09607237]
# While there is 5 principal components, explained variation per principal component: [0.20715348 0.11070825 0.10003384 0.09607237 0.09187079]
# While there is 6 principal components, explained variation per principal component: [0.20715348 0.11070825 0.10003384 0.09607237 0.09187079 0.08845826]
# While there is 7 principal components, explained variation per principal component: [0.20715348 0.11070825 0.10003384 0.09607237 0.09187079 0.08845826
#  0.08565904]
# While there is 8 principal components, explained variation per principal component: [0.20715348 0.11070825 0.10003384 0.09607237 0.09187079 0.08845826
#  0.08565904 0.08165053]
# While there is 9 principal components, explained variation per principal component: [0.20715348 0.11070825 0.10003384 0.09607237 0.09187079 0.08845826
#  0.08565904 0.08165053 0.07339863]
# While there is 10 principal components, explained variation per principal component: [0.20715348 0.11070825 0.10003384 0.09607237 0.09187079 0.08845826
#  0.08565904 0.08165053 0.07339863 0.05830268]
